# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve2d

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from keras import regularizers

# %%
# %matplotlib notebook

# %%
train_images = np.load("../train_images.npy")
train_images = np.reshape(train_images, (50_000, 28, 28))

with open('../train_labels.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    train_labels = np.array(list(reader))[1:,1]
    
labels = np.zeros((10, 10))
for i in range(10):
    labels[i, i] = 1

train_labels = np.array([labels[int(x), :] for x in train_labels])

# %%
def to_image(idx):
    return np.reshape(train_images[idx], (28, 28)).astype(np.uint8)

def show_image(arr):
    two_d = np.reshape(arr, (28, 28)).astype(np.uint8)
    plt.figure()
    plt.imshow(two_d, cmap='gray', interpolation='nearest')
    plt.show()

show_image(train_images[0])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def find_holes(im, threshold=100):
    kernel = [[1, 1, 1], [1, -8, 1], [1, 1, 1]]
    conv = convolve2d(im, kernel, mode='same')
    max_diff = np.max(conv)
    return np.maximum(0, np.minimum(255, 255 * conv / max_diff)) > threshold
    
def fix_holes(im, holes=None, threshold=100):
    if holes is None:
        holes = find_holes(im, threshold)
        
    kernel = 1/8 * np.array([[1, 1, 1], [1, 0, 1], [1, 1, 1]])
    conv = convolve2d(im, kernel, mode='same')
    result = np.array(im)
    result[holes] = conv[holes].flatten()
    result[result < 100] = 0
    return result.flatten()

train_images_no_holes = np.array([fix_holes(im) for im in train_images])

# %%
valid_x = train_images_no_holes[:10_000, :]
valid_y = train_labels[:10_000, :]

train_x = train_images_no_holes[10_000:, :]
train_y = train_labels[10_000:, :]

# %%
model = Sequential()

model.add(Dense(units=600, activation='sigmoid', input_dim=784, kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(units=400, activation='sigmoid', input_dim=200, kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(units=10, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(learning_rate=0.06, rho=0.95),
              metrics=[keras.metrics.BinaryAccuracy()])

# %%
model.fit(train_x, train_y, epochs=10, batch_size=256)
# Out:
# Epoch 1/10
# 40000/40000 [==============================] - 3s 73us/step - loss: 12.2342 - binary_accuracy: 0.9006
# Epoch 2/10
# 40000/40000 [==============================] - 3s 68us/step - loss: 9.6522 - binary_accuracy: 0.9185
# Epoch 3/10
# 40000/40000 [==============================] - 3s 68us/step - loss: 7.8048 - binary_accuracy: 0.9355
# Epoch 4/10
# 40000/40000 [==============================] - 3s 68us/step - loss: 6.4113 - binary_accuracy: 0.9437
# Epoch 5/10
# 40000/40000 [==============================] - 3s 68us/step - loss: 5.3593 - binary_accuracy: 0.9481
# Epoch 6/10
# 40000/40000 [==============================] - 3s 68us/step - loss: 4.5567 - binary_accuracy: 0.9510
# Epoch 7/10
# 40000/40000 [==============================] - 3s 68us/step - loss: 3.9394 - binary_accuracy: 0.9529
# Epoch 8/10
# 40000/40000 [==============================] - 3s 68us/step - loss: 3.4575 - binary_accuracy: 0.9543
# Epoch 9/10
# 40000/40000 [==============================] - 3s 68us/step - loss: 3.0745 - binary_accuracy: 0.9558
# Epoch 10/10
# 40000/40000 [==============================] - 3s 69us/step - loss: 2.7656 - binary_accuracy: 0.9570

# %%
loss_and_metrics = model.evaluate(valid_x, valid_y, batch_size=256)
print(loss_and_metrics)
# Out:
# 10000/10000 [==============================] - 0s 28us/step
# [2.6495504497528075, 0.9565500020980835]

# %%
test_images = np.load("../test_images.npy")
test_images = np.reshape(test_images, (-1, 28, 28))
print(test_images.shape)
# Out:
# (20000, 28, 28)

# %%
test_images_no_holes = np.array([fix_holes(im) for im in test_images])

# %%
#show_image(test_images[0])
#show_image(test_images_no_holes[0])

# %%
classes = model.predict(test_images_no_holes).argmax(axis=1)
print(classes.shape)
# Out:
# (20000,)

# %%
with open('submission.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    writer.writerow(['ID', 'label'])
    for idx, val in enumerate(classes):
        writer.writerow([str(idx), str(val)])

# %% [markdown]
# # Convolutional Neural Network

# %%
model2 = Sequential()

model2.add(Conv2D(filters=64, kernel_size=5, activation='sigmoid', 
                  input_shape=(28, 28, 1), kernel_regularizer=regularizers.l2(0.01)))

model2.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))
model2.add(Conv2D(filters=32, kernel_size=5, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)))

model2.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))
model2.add(Conv2D(filters=32, kernel_size=3, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)))

model2.add(Flatten())
model2.add(Dense(units=10, activation='softmax'))

model2.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(learning_rate=0.1, rho=0.95),
              metrics=[keras.metrics.BinaryAccuracy()])

# %%
train_x_conv = train_x.reshape((-1, 28, 28, 1)) / 255
valid_x_conv = valid_x.reshape((-1, 28, 28, 1)) / 255

# %%
model2.fit(train_x_conv, train_y, epochs=10, batch_size=256)
# Out:
# Epoch 1/10
# 40000/40000 [==============================] - 34s 848us/step - loss: 2.2437 - binary_accuracy: 0.8979
# Epoch 2/10
# 40000/40000 [==============================] - 37s 937us/step - loss: 1.7902 - binary_accuracy: 0.9030
# Epoch 3/10
# 40000/40000 [==============================] - 34s 858us/step - loss: 1.5739 - binary_accuracy: 0.9143
# Epoch 4/10
# 40000/40000 [==============================] - 36s 889us/step - loss: 1.4860 - binary_accuracy: 0.9231
# Epoch 5/10
# 40000/40000 [==============================] - 35s 869us/step - loss: 1.4381 - binary_accuracy: 0.9271
# Epoch 6/10
# 40000/40000 [==============================] - 34s 854us/step - loss: 1.4051 - binary_accuracy: 0.9294
# Epoch 7/10
# 40000/40000 [==============================] - 34s 857us/step - loss: 1.3798 - binary_accuracy: 0.9307
# Epoch 8/10
# 40000/40000 [==============================] - 34s 855us/step - loss: 1.3593 - binary_accuracy: 0.9315
# Epoch 9/10
# 40000/40000 [==============================] - 35s 864us/step - loss: 1.3429 - binary_accuracy: 0.9320
# Epoch 10/10
# 40000/40000 [==============================] - 34s 850us/step - loss: 1.3274 - binary_accuracy: 0.9326

# %%
loss_and_metrics = model2.evaluate(valid_x_conv, valid_y, batch_size=256)
print(loss_and_metrics)
# Out:
# 10000/10000 [==============================] - 3s 253us/step
# [1.3589767217636108, 0.931679904460907]

# %%
test_images_no_holes_conv = test_images_no_holes.reshape((-1, 28, 28, 1)) / 255
classes = model2.predict(test_images_no_holes_conv).argmax(axis=1)
with open('submission2.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    writer.writerow(['ID', 'label'])
    for idx, val in enumerate(classes):
        writer.writerow([str(idx), str(val)])

# %%
print(model2.predict(test_images_no_holes_conv)[0, :])
# Out:
# [0.17064887 0.06433936 0.13838695 0.09810541 0.10076405 0.0478199
#  0.23354475 0.02984181 0.10254013 0.01400881]

# %%
classes2 = classes
classes1 = model.predict(test_images_no_holes).argmax(axis=1)

count = 0
for x, y in zip(classes1, classes2):
    if x != y:
        count += 1
    
    
print(count)
# Out:
# 5803

# %%
print((classes2 == 9).sum())
# Out:
# 4060

# %%
classes
# Out:
# array([9, 5, 2, ..., 3, 8, 2], dtype=int64)
